# %%
import scipy.signal as sig
import numpy as np
import matplotlib as mpl
from matplotlib import pyplot as plt
import pandas as pd
import scipy.optimize as so
import os

# %%
nhead = 6
toVolt = 39.3216/((2**24) -1)
touAmp= (77/55)*toVolt

# %%
for i in range(4):
    file_path = r"C:\Users\n1cos\Downloads\clusterCryostatRun18\noise\noise_SQ"+ str(i + 1) + "_000.bin"
    #print("squidchar_noise_186" + str(i+1)+"M")
    fs=100e3
    nperseg=int(0.5*fs)
    
    if os.path.isfile(file_path):
        #readRDT(file_path)
        fd = open(file_path, 'rb')
        read_data = np.fromfile(file=fd, dtype=np.int32)
        fd.close()
        read_data= toVolt*read_data[12:]/1.70
        f, pxx = sig.welch(read_data, fs=fs, nperseg=nperseg)
        f = f[:-1]
        ppx = 1e6 * np.sqrt(pxx[:-1])
        P10 = np.mean(ppx[(f >= 7) & (f <= 11)])
        P103 = np.mean(ppx[(f >= 900) & (f <= 1100)])
        print(P10)
        plt.plot(f, ppx,label=f"SQUID_"+ str(i + 1))
        
    else:
        print("No data taken")
#plt.title("QUAD 185",fontsize= 16)
#plt.axhline(y=4, color='r', linestyle='--', linewidth=5,label=" Shunt Noise")
plt.legend()
plt.title("QUAD 107")
plt.yscale("log")
plt.xscale("log")
plt.grid(True)
plt.xlabel(r'$f$ [Hz]', fontsize= 16)
plt.ylabel(r'$ \frac{p A}{\sqrt{Hz}}$', fontsize= 16)
plt.show()
# Out:
# 118.40323233503123
# 84.1446875421932
# 5.706495782932825
# 113.8712366016992

# %%
for i in range(4):
    file_path = r"C:\Users\n1cos\Downloads\clusterCryostatRun18\noise\noise_SQ"+ str(i + 5) + "_000.bin"
    #print("squidchar_noise_186" + str(i+1)+"M")
    fs=100e3
    nperseg=int(0.5*fs)
    
    if os.path.isfile(file_path):
        #readRDT(file_path)
        fd = open(file_path, 'rb')
        read_data = np.fromfile(file=fd, dtype=np.int32)
        fd.close()
        read_data= toVolt*read_data[12:]/1.70
        f, pxx = sig.welch(read_data, fs=fs, nperseg=nperseg)
        f = f[:-1]
        ppx = 1e6 * np.sqrt(pxx[:-1])
        P10 = np.mean(ppx[(f >= 7) & (f <= 11)])
        P103 = np.mean(ppx[(f >= 900) & (f <= 1100)])
        print(P10)
        plt.plot(f, ppx,label=f"SQUID_"+ str(i + 5))
        
    else:
        print("No data taken")
#plt.title("QUAD 185",fontsize= 16)
#plt.axhline(y=4, color='r', linestyle='--', linewidth=5,label=" Shunt Noise")
plt.legend()
plt.title("QUAD 189")
plt.yscale("log")
plt.xscale("log")
plt.grid(True)
plt.xlabel(r'$f$ [Hz]', fontsize= 16)
plt.ylabel(r'$ \frac{p A}{\sqrt{Hz}}$', fontsize= 16)
plt.show()
# Out:
# 149.8977673103845
# 124.60519960577922
# 145.85892673866923
# 96.99968484197183

# %%
for i in range(8):
    file_path = r"C:\Users\n1cos\Downloads\clusterCryostatRun18\noise\noise_SQ"+ str(i + 1) + "_000_PTOFF.bin"
    fs=100e3
    nperseg=int(0.5*fs)
    
    if os.path.isfile(file_path):
        #readRDT(file_path)
        fd = open(file_path, 'rb')
        read_data = np.fromfile(file=fd, dtype=np.int32)
        fd.close()
        read_data= toVolt*read_data[12:]/1.70
        f, pxx = sig.welch(read_data, fs=fs, nperseg=nperseg)
        f = f[:-1]
        ppx = 1e6 * np.sqrt(pxx[:-1])
        P10 = np.mean(ppx[(f >= 7) & (f <= 11)])
        P103 = np.mean(ppx[(f >= 900) & (f <= 1100)])
        print(P10)
        plt.plot(f, ppx,label=f"SQUID_"+ str(i + 1))
        
    else:
        print("No data taken")
#plt.title("QUAD 185",fontsize= 16)
#plt.axhline(y=4, color='r', linestyle='--', linewidth=5,label=" Shunt Noise")
plt.legend()
plt.yscale("log")
plt.xscale("log")
plt.grid(True)
plt.title("ClusterCryostatRun18\ Noise\ OFF")
plt.xlabel(r'$f$ [Hz]', fontsize= 16)
plt.ylabel(r'$ \frac{p A}{\sqrt{Hz}}$', fontsize= 16)
plt.show()
# Out:
# 125.74621084576124
# 95.0604961280817
# 5.122841950141607
# nan
# No data taken
# No data taken
# No data taken
# 117.29788418661605

# %%
for i in range (8):
    file_path = r"C:\Users\n1cos\Downloads\clusterCryostatRun18\noise\noise_SQ"+ str(i + 1) + "_000.bin"
    fs=100e3
    nperseg=int(0.5*fs)
    
    os.path.isfile(file_path)
#readRDT(file_path)
    fd = open(file_path, 'rb')
    read_data = np.fromfile(file=fd, dtype=np.int32)
    fd.close()
    read_data= toVolt*read_data[12:]/1.70
    f, pxx = sig.welch(read_data, fs=fs, nperseg=nperseg)
    f = f[:-1]
    ppx = 1e6 * np.sqrt(pxx[:-1])
    P10 = np.mean(ppx[(f >= 7) & (f <= 11)])
    P103 = np.mean(ppx[(f >= 900) & (f <= 1100)])
    print(P10)
    plt.plot(f, ppx,label=f"SQUID_"+ str(i + 1) + "_PTON")
    file_path = r"C:\Users\n1cos\Downloads\clusterCryostatRun18\noise\noise_SQ"+ str(i + 1) + "_000_PTOFF.bin"
    fs=100e3
    nperseg=int(0.5*fs)
    
    os.path.isfile(file_path)
#readRDT(file_path)
    fd = open(file_path, 'rb')
    read_data = np.fromfile(file=fd, dtype=np.int32)
    fd.close()
    read_data= toVolt*read_data[12:]/1.70
    f, pxx = sig.welch(read_data, fs=fs, nperseg=nperseg)
    f = f[:-1]
    ppx = 1e6 * np.sqrt(pxx[:-1])
    P10 = np.mean(ppx[(f >= 7) & (f <= 11)])
    P103 = np.mean(ppx[(f >= 900) & (f <= 1100)])
    print(P10)
    plt.plot(f, ppx,label=f"SQUID_"+ str(i + 1) + "_PTOFF")
    #plt.title("QUAD 185",fontsize= 16)
    #plt.axhline(y=4, color='r', linestyle='--', linewidth=5,label=" Shunt Noise")
    plt.legend()
    plt.yscale("log")
    plt.xscale("log")
    plt.grid(True)
    plt.title("ClusterCryostatRun18\ Noise\ OFF")
    plt.xlabel(r'$f$ [Hz]', fontsize= 16)
    plt.ylabel(r'$ \frac{p A}{\sqrt{Hz}}$', fontsize= 16)
    plt.show()
# Out:
# 118.40323233503123
# 125.74621084576124
# 84.1446875421932
# 95.0604961280817
# 5.706495782932825
# 5.122841950141607
# 113.8712366016992
# nan
# C:\Users\n1cos\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3440: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\n1cos\anaconda3\lib\site-packages\numpy\core\_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# 149.8977673103845
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3140\1969001720.py in <module>
#      23     os.path.isfile(file_path)
#      24 #readRDT(file_path)
# ---> 25     fd = open(file_path, 'rb')
#      26     read_data = np.fromfile(file=fd, dtype=np.int32)
#      27     fd.close()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\n1cos\\Downloads\\clusterCryostatRun18\\noise\\noise_SQ5_000_PTOFF.bin'

# %%
file_path = r"C:\Users\n1cos\Downloads\clusterCryostatRun18\noise\noise_SQ190-3_000_PTON.bin"
fs=100e3
nperseg=int(0.5*fs)
    
os.path.isfile(file_path)
#readRDT(file_path)
fd = open(file_path, 'rb')
read_data = np.fromfile(file=fd, dtype=np.int32)
fd.close()
read_data= toVolt*read_data[12:]/1.70
f, pxx = sig.welch(read_data, fs=fs, nperseg=nperseg)
f = f[:-1]
ppx = 1e6 * np.sqrt(pxx[:-1])
P10 = np.mean(ppx[(f >= 7) & (f <= 11)])
P103 = np.mean(ppx[(f >= 900) & (f <= 1100)])
print(P10)
plt.plot(f, ppx,label=f"SQUID_190_3_PTON")
file_path = r"C:\Users\n1cos\Downloads\clusterCryostatRun18\noise\noise_SQ190-3_000_PTOFF.bin"
fs=100e3
nperseg=int(0.5*fs)
    
os.path.isfile(file_path)
#readRDT(file_path)
fd = open(file_path, 'rb')
read_data = np.fromfile(file=fd, dtype=np.int32)
fd.close()
read_data= toVolt*read_data[12:]/1.70
f, pxx = sig.welch(read_data, fs=fs, nperseg=nperseg)
f = f[:-1]
ppx = 1e6 * np.sqrt(pxx[:-1])
P10 = np.mean(ppx[(f >= 7) & (f <= 11)])
P103 = np.mean(ppx[(f >= 900) & (f <= 1100)])
print(P10)
plt.plot(f, ppx,label=f"SQUID_190_3_PTOFF")
#plt.title("QUAD 185",fontsize= 16)
#plt.axhline(y=4, color='r', linestyle='--', linewidth=5,label=" Shunt Noise")
plt.legend()
plt.yscale("log")
plt.xscale("log")
plt.grid(True)
plt.title("ClusterCryostatRun18\ Noise\ OFF")
plt.xlabel(r'$f$ [Hz]', fontsize= 16)
plt.ylabel(r'$ \frac{p A}{\sqrt{Hz}}$', fontsize= 16)
plt.show()
# Out:
# 3.7739638938315596
# 3.6803160691895647
